# %%
from performance_plots import plot_mse_with_break,plot_mse_without_break, boxplots_one_epoch
import matplotlib.pyplot as plt

# %%
plt.style.use('default')
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 15

import config # contains the paths to the data

# %% [markdown]
# ## Vanilla RNN

# %%
RNN_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/RNN'
RNN_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Shuffled_Directional']
RNN_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained', 'DirectedProp Shuffled']
RNN_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                     {'color': '#d6a319', 'marker': 'x'},
                     {'color': '#4cc997', 'marker': 'v'},
                     {'color': '#cc323f', 'marker': '.'}]
RNN_save_path = "figures/Figure_2/RNN"

# %%
for epoch in [0, 1, 'max']:
    boxplots_one_epoch(epoch=epoch,
                       parent_dir=RNN_parent_dir,
                       model_dirs=RNN_model_dirs,
                       model_names=RNN_model_names,
                       model_designs=RNN_model_designs,
                       save_path=RNN_save_path,
                       cell_type='RNN',
                       measurement='loss',
                       ylim='auto',
                       show_legend=False)
# Out:
# DirectedProp: Epoch 24
# NotDirectedProp: Epoch 40
# NotPretrained: Epoch 28
# DirectedProp Shuffled: Epoch 36

# %%
# Plot training curves
plot_mse_with_break(parent_dir=RNN_parent_dir, model_dirs=RNN_model_dirs, model_names=RNN_model_names, model_designs=RNN_model_designs, save_path=RNN_save_path, cell_type='RNN', dataset='train', ylim=(9,125), figsize=(6,4.5), start_break=25, end_break=40, width_ratios=[5,1])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir, model_dirs=RNN_model_dirs, model_names=RNN_model_names, model_designs=RNN_model_designs, save_path=RNN_save_path, cell_type='RNN', dataset='validation', ylim=(9,100), show_epoch_zero_vali=False, figsize=(6,4.5), start_break=25, end_break=40, width_ratios=[5,1], print_epoch_zero=True, print_epoch_one=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Pretrained_Directional - Epoch 0: Mean MSE: 271.7254968, SEM: 7.37115212500952
# Pretrained_Directional - Epoch 1: Mean MSE: 54.9945722, SEM: 2.6308722669201816
# Pretrained_Godfrey - Epoch 0: Mean MSE: 220.6316884, SEM: 16.443501847980283
# Pretrained_Godfrey - Epoch 1: Mean MSE: 60.0762766, SEM: 2.6419173599238976
# No_Pretraining - Epoch 0: Mean MSE: 447.9380984, SEM: 90.25237088280409
# No_Pretraining - Epoch 1: Mean MSE: 92.8166596, SEM: 1.0049438029553988
# Shuffled_Directional - Epoch 0: Mean MSE: 444.728216, SEM: 146.28779547662464
# ...

# %% [markdown]
# ## LSTM

# %%
LSTM_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/LSTM'
LSTM_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Shuffled_Directional']
LSTM_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained', 'DirectedProp Shuffled']
LSTM_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#d6a319', 'marker': 'x'},
                 {'color': '#4cc997', 'marker': 'v'}, {'color': '#cc323f', 'marker': '.'}]
LSTM_save_path = 'figures/Supplementary_Figures/Performance_Plots'

# %%
plot_mse_without_break(parent_dir=LSTM_parent_dir, model_dirs=LSTM_model_dirs, model_names=LSTM_model_names, model_designs=LSTM_model_designs, save_path=LSTM_save_path, cell_type='LSTM', dataset='train', nr_epochs=9, figsize=(4.5,4.5), ylim=(10,125), show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=LSTM_parent_dir, model_dirs=LSTM_model_dirs, model_names=LSTM_model_names, model_designs=LSTM_model_designs, save_path=LSTM_save_path, cell_type='LSTM', dataset='validation', nr_epochs=9,figsize=(4.5,4.5), ylim=(10,125), show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## GRU

# %%
GRU_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/GRU'
GRU_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Shuffled_Directional']
GRU_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained', 'DirectedProp Shuffled']
GRU_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#d6a319', 'marker': 'x'},
                 {'color': '#4cc997', 'marker': 'v'}, {'color': '#cc323f', 'marker': '.'}]
GRU_save_path = 'figures/Supplementary_Figures/Performance_Plots'

# %%
plot_mse_without_break(parent_dir=GRU_parent_dir, model_dirs=GRU_model_dirs, model_names=GRU_model_names, model_designs=GRU_model_designs, save_path=GRU_save_path, cell_type='GRU', dataset='train', nr_epochs=9, figsize=(4.5,4.5), ylim=(10,137), show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=GRU_parent_dir, model_dirs=GRU_model_dirs, model_names=GRU_model_names, model_designs=GRU_model_designs, save_path=GRU_save_path, cell_type='GRU', dataset='validation', nr_epochs=9,figsize=(4.5,4.5), ylim=(10,95), show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Pre-trained for one epoch

# %% [markdown]
# ### Vanilla RNN

# %%
RNN1_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/RNN'
RNN1_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
RNN1_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
RNN1_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
RNN1_save_path = "figures/Figure_4/"

# %%
plot_mse_with_break(parent_dir=RNN1_parent_dir,
                    model_dirs=RNN1_model_dirs,
                    model_names=RNN1_model_names,
                    model_designs=RNN1_model_designs,
                    save_path=RNN1_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(9,119),
                    figsize=(6,4.5),
                    start_break=25,
                    end_break=40,
                    width_ratios=[5,1],
                    skip_epoch=['Pre-trained with\ndirectional bias\nfor one epoch',1]
                    )
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN1_parent_dir, model_dirs=RNN1_model_dirs, model_names=RNN1_model_names, model_designs=RNN1_model_designs, save_path=RNN1_save_path, cell_type='RNN', dataset='validation', ylim=(9,97), figsize=(6,4.5), start_break=25, end_break=40, width_ratios=[5,1], skip_epoch=['Pre-trained with\ndirectional bias\nfor one epoch',1])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### LSTM

# %%
LSTM1_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/LSTM'
LSTM1_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
LSTM1_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
LSTM1_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
LSTM1_save_path = 'figures/Supplementary_Figures/Figure_S2'

# %%
plot_mse_without_break(parent_dir=LSTM1_parent_dir, model_dirs=LSTM1_model_dirs, model_names=LSTM1_model_names, model_designs=LSTM1_model_designs, save_path=LSTM1_save_path, cell_type='LSTM', dataset='train', nr_epochs=8,figsize=(4.5,4.5), ylim=(10,113), skip_epoch=['Pre-trained with\ndirectional bias\nfor one epoch',1], show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=LSTM1_parent_dir, model_dirs=LSTM1_model_dirs, model_names=LSTM1_model_names, model_designs=LSTM1_model_designs, save_path=LSTM1_save_path, cell_type='LSTM', dataset='validation', nr_epochs=9,figsize=(4.5,4.5), ylim=(10,125), skip_epoch=['Pre-trained with\ndirectional bias\nfor one epoch',1], show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### GRU

# %%
GRU1_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/GRU'
GRU1_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
GRU1_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
GRU1_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
GRU1_save_path = 'figures/Supplementary_Figures/Figure_S2'

# %%
plot_mse_without_break(parent_dir=GRU1_parent_dir, model_dirs=GRU1_model_dirs, model_names=GRU1_model_names, model_designs=GRU1_model_designs, save_path=GRU1_save_path, cell_type='GRU', dataset='train', nr_epochs=9,figsize=(4.5,4.5), ylim=(10,138), skip_epoch=['Pre-trained with\ndirectional bias\nfor one epoch',1], show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=GRU1_parent_dir, model_dirs=GRU1_model_dirs, model_names=GRU1_model_names, model_designs=GRU1_model_designs, save_path=GRU1_save_path, cell_type='GRU', dataset='validation', nr_epochs=9,figsize=(4.5,4.5), ylim=(10,95), skip_epoch=['Pre-trained with\ndirectional bias\nfor one epoch',1], show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Pre-trained for two and four epochs - Vanilla RNN

# %%
RNN2_4_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/RNN'
RNN2_4_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_TWO_EPOCHS', 'Pretrained_Directional_FOUR_EPOCHS']
RNN2_4_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\ntwo epochs', 'DirectedProp\nfour epochs']
RNN2_4_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                        {'color': '#4cc997', 'marker': 'v'},
                        {'color': '#e699ff', 'marker': 'P'},
                        {'color': '#f1854f', 'marker': 'P'}]
RNN2_4_save_path = "figures/Figure_4/"

# %%
plot_mse_with_break(parent_dir=RNN2_4_parent_dir,
                    model_dirs=RNN2_4_model_dirs, 
                    model_names=RNN2_4_model_names, 
                    model_designs=RNN2_4_model_designs, 
                    save_path=RNN2_4_save_path, 
                    cell_type='RNN', 
                    dataset='train', 
                    figsize=(6,4.5),
                    ylim=(10,119), 
                    start_break=25, 
                    end_break=40, 
                    width_ratios=[5,1], 
                    skip_epoch=[('DirectedProp\ntwo epochs',2), 
                                ('DirectedProp\nfour epochs',4)],
                    )
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN2_4_parent_dir,
                    model_dirs=RNN2_4_model_dirs, 
                    model_names=RNN2_4_model_names, 
                    model_designs=RNN2_4_model_designs, 
                    save_path=RNN2_4_save_path, 
                    cell_type='RNN', 
                    dataset='validation', 
                    figsize=(6,4.5), 
                    ylim=(9,100), 
                    start_break=25, 
                    end_break=40, 
                    width_ratios=[5,1], 
                    skip_epoch=[('DirectedProp\ntwo epochs',2), 
                                ('DirectedProp\nfour epochs',4)],
                    )
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Pre-trained for two epochs - Vanilla RNN

# %%
RNN2_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/RNN'
RNN2_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_TWO_EPOCHS']
RNN2_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\ntwo epochs']
RNN2_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#e699ff', 'marker': 'P'}]
RNN2_save_path = "figures/Figure_4/"

# %%
plot_mse_with_break(parent_dir=RNN2_parent_dir, model_dirs=RNN2_model_dirs, model_names=RNN2_model_names, model_designs=RNN2_model_designs, save_path=RNN2_save_path, cell_type='RNN', dataset='train', figsize=(6,4.5), ylim=(10,119), start_break=25, end_break=40, width_ratios=[5,1], skip_epoch=['Pre-trained with\ndirectional bias\nfor two epochs',2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN2_parent_dir, model_dirs=RNN2_model_dirs, model_names=RNN2_model_names, model_designs=RNN2_model_designs, save_path=RNN2_save_path, cell_type='RNN', dataset='validation', figsize=(6,4.5), ylim=(9,119), start_break=25, end_break=40, width_ratios=[5,1], skip_epoch=['Pre-trained with\ndirectional bias\nfor two epochs',2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Pre-trained for four epochs - Vanilla RNN

# %%
RNN4_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/RNN'
RNN4_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_FOUR_EPOCHS']
RNN4_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\nfour epochs']
RNN4_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#f1854f', 'marker': 'P'}]
RNN4_save_path = "figures/Figure_4/"

# %%
plot_mse_with_break(parent_dir=RNN4_parent_dir, model_dirs=RNN4_model_dirs, model_names=RNN4_model_names, model_designs=RNN4_model_designs, save_path=RNN4_save_path, cell_type='RNN', dataset='train', figsize=(6,4.5), ylim=(10,119), start_break=25, end_break=40, width_ratios=[5,1], skip_epoch=['Pre-trained with\ndirectional bias\nfor four epochs',4])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN4_parent_dir, model_dirs=RNN4_model_dirs, model_names=RNN4_model_names, model_designs=RNN4_model_designs, save_path=RNN4_save_path, cell_type='RNN', dataset='validation', figsize=(6,4.5), ylim=(10,119), start_break=25, end_break=40, width_ratios=[5,1], skip_epoch=['Pre-trained with\ndirectional bias\nfor four epochs',4])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Pre-trained with undirectioanal RWs

# %%
RNN_parent_dir = f'{config.project_dir}/01_Output/Training_Output/NI_Maze_Dataset/RNN'
RNN_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Pretrained_UNdirectional']
RNN_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained',
                'Pre-trained with\nRWs propagating in\nall directions']
RNN_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                     {'color': '#d6a319', 'marker': 'x'},
                     {'color': '#4cc997', 'marker': 'v'},
                     {'color': '#cc0099', 'marker': '*'}]
RNN_save_path = 'figures/Supplementary_Figures/Figure_S1'

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir, model_dirs=RNN_model_dirs, model_names=RNN_model_names, model_designs=RNN_model_designs, save_path=RNN_save_path, cell_type='RNN', dataset='train', ylim=(9,132), figsize=(6,4.5), start_break=25, end_break=40, width_ratios=[5,1])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir, model_dirs=RNN_model_dirs, model_names=RNN_model_names, model_designs=RNN_model_designs, save_path=RNN_save_path, cell_type='RNN', dataset='validation', ylim=(9,100), figsize=(6,4.5), start_break=25, end_break=40, width_ratios=[5,1])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # CatCam dataset

# %%
RNN_catcam_parent_dir = f'{config.project_dir}/01_Output/Training_Output/CatCam_Dataset/RNN'
RNN_catcam_model_dirs = ['Pretrained_Directional', 'No_Pretraining']
RNN_catcam_model_names = ['DirectedProp', 'NotPretrained']
RNN_catcam_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                 {'color': '#4cc997', 'marker': 'v'}]
RNN_catcam_save_path = 'figures/Figure_3'

# %%
plot_mse_without_break(parent_dir=RNN_catcam_parent_dir, model_dirs=RNN_catcam_model_dirs, model_names=RNN_catcam_model_names, model_designs=RNN_catcam_model_designs, save_path=RNN_catcam_save_path, cell_type='RNN', dataset='train', nr_epochs=24, figsize=(7,4.5), ylim=(73,170), show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=RNN_catcam_parent_dir, model_dirs=RNN_catcam_model_dirs, model_names=RNN_catcam_model_names, model_designs=RNN_catcam_model_designs, save_path=RNN_catcam_save_path, cell_type='RNN', dataset='validation', nr_epochs=24, ylim=(75,142), figsize=(7,4.5), show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
