# %%
from performance_plots import plot_mse_with_break, plot_mse_without_break, boxplots_one_epoch
import matplotlib.pyplot as plt

# %%
plt.style.use('default')
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 15

import config # contains the paths to the data

# %% [markdown]
# ## Vanilla RNN

# %%
RNN_parent_dir = f'{config.project_dir}/Output/NI_maze/RNN'
RNN_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Shuffled_Directional']
RNN_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained', 'DirectedProp Shuffled']
RNN_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                     {'color': '#d6a319', 'marker': 'x'},
                     {'color': '#4cc997', 'marker': 'v'},
                     {'color': '#cc323f', 'marker': '.'}]
RNN_save_path = "figures_revisions/Figure_2"

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,175),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,127),
                    show_epoch_zero_vali=False,
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2],
                    print_epoch_zero=True,
                    print_epoch_one=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Pretrained_Directional - Epoch 0: Mean MSE: 231.4059492, SD: 12.087014798599574
# Pretrained_Directional - Epoch 1: Mean MSE: 48.7070866, SD: 17.756653149040538
# Pretrained_Godfrey - Epoch 0: Mean MSE: 262.999163, SD: 47.1005209212578
# Pretrained_Godfrey - Epoch 1: Mean MSE: 63.6752086, SD: 9.638240367642206
# No_Pretraining - Epoch 0: Mean MSE: 623.0150275999999, SD: 199.69426518900949
# No_Pretraining - Epoch 1: Mean MSE: 123.1565442, SD: 6.531063562102132
# Shuffled_Directional - Epoch 0: Mean MSE: 475.5330466, SD: 338.65326332120077
# ...

# %% [markdown]
# ## LSTM

# %%
LSTM_parent_dir = f'{config.project_dir}/Output/NI_maze/LSTM'
LSTM_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Shuffled_Directional']
LSTM_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained', 'DirectedProp\nShuffled']
LSTM_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                      {'color': '#d6a319', 'marker': 'x'},
                      {'color': '#4cc997', 'marker': 'v'}, 
                      {'color': '#cc323f', 'marker': '.'}]
LSTM_save_path = 'figures_revisions/Figure_S1'

# %%
plot_mse_without_break(parent_dir=LSTM_parent_dir,
                       model_dirs=LSTM_model_dirs,
                       model_names=LSTM_model_names,
                       model_designs=LSTM_model_designs,
                       save_path=LSTM_save_path,
                       cell_type='LSTM',
                       dataset='train',
                       nr_epochs=9,
                       figsize=(4.5,4.5),
                       ylim=(0,136),
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=LSTM_parent_dir,
                       model_dirs=LSTM_model_dirs,
                       model_names=LSTM_model_names,
                       model_designs=LSTM_model_designs,
                       save_path=LSTM_save_path,
                       cell_type='LSTM',
                       dataset='validation',
                       nr_epochs=9,
                       figsize=(4.5,4.5),
                       ylim=(0,160),
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## GRU

# %%
GRU_parent_dir = f'{config.project_dir}/Output/NI_maze/GRU'
GRU_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Shuffled_Directional']
GRU_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained', 'DirectedProp\nShuffled']
GRU_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                     {'color': '#d6a319', 'marker': 'x'},
                     {'color': '#4cc997', 'marker': 'v'},
                     {'color': '#cc323f', 'marker': '.'}]
GRU_save_path = 'figures_revisions/Figure_S1'

# %%
plot_mse_without_break(parent_dir=GRU_parent_dir,
                       model_dirs=GRU_model_dirs,
                       model_names=GRU_model_names,
                       model_designs=GRU_model_designs,
                       save_path=GRU_save_path,
                       cell_type='GRU',
                       dataset='train',
                       nr_epochs=9,
                       figsize=(4.5,4.5),
                       ylim=(0,125),
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=GRU_parent_dir,
                       model_dirs=GRU_model_dirs,
                       model_names=GRU_model_names,
                       model_designs=GRU_model_designs,
                       save_path=GRU_save_path,
                       cell_type='GRU',
                       dataset='validation',
                       nr_epochs=9,
                       figsize=(4.5,4.5),
                       ylim=(0,97),
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Pre-trained for one epoch

# %% [markdown]
# ### Vanilla RNN

# %%
RNN1_parent_dir = f'{config.project_dir}/Output/NI_maze/RNN'
RNN1_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
RNN1_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
RNN1_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
RNN1_save_path = "figures_revisions/Figure_4/"

# %%
plot_mse_with_break(parent_dir=RNN1_parent_dir,
                    model_dirs=RNN1_model_dirs,
                    model_names=RNN1_model_names,
                    model_designs=RNN1_model_designs,
                    save_path=RNN1_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,175),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN1_parent_dir,
                    model_dirs=RNN1_model_dirs,
                    model_names=RNN1_model_names,
                    model_designs=RNN1_model_designs,
                    save_path=RNN1_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,127),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### LSTM

# %%
LSTM1_parent_dir = f'{config.project_dir}/Output/NI_maze/LSTM'
LSTM1_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
LSTM1_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
LSTM1_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
LSTM1_save_path = 'figures_revisions/Figure_S2'

# %%
plot_mse_without_break(parent_dir=LSTM1_parent_dir,
                       model_dirs=LSTM1_model_dirs,
                       model_names=LSTM1_model_names,
                       model_designs=LSTM1_model_designs,
                       save_path=LSTM1_save_path,
                       cell_type='LSTM',
                       dataset='train',
                       nr_epochs=8,
                       figsize=(4.5,4.5),
                       ylim=(0,135),
                       skip_epoch=[('DirectedProp\none epoch',1)],
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=LSTM1_parent_dir,
                       model_dirs=LSTM1_model_dirs,
                       model_names=LSTM1_model_names,
                       model_designs=LSTM1_model_designs,
                       save_path=LSTM1_save_path,
                       cell_type='LSTM',
                       dataset='validation',
                       nr_epochs=9,
                       figsize=(4.5,4.5),
                       ylim=(0,163),
                       skip_epoch=[('DirectedProp\none epoch',1)],
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### GRU

# %%
GRU1_parent_dir = f'{config.project_dir}/Output/NI_maze/GRU'
GRU1_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
GRU1_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
GRU1_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
GRU1_save_path = 'figures_revisions/Figure_S2'

# %%
plot_mse_without_break(parent_dir=GRU1_parent_dir,
                       model_dirs=GRU1_model_dirs,
                       model_names=GRU1_model_names,
                       model_designs=GRU1_model_designs,
                       save_path=GRU1_save_path,
                       cell_type='GRU',
                       dataset='train',
                       nr_epochs=9,
                       figsize=(4.5,4.5),
                       ylim=(0,120),
                       skip_epoch=[('DirectedProp\none epoch',1)],
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=GRU1_parent_dir,
                       model_dirs=GRU1_model_dirs,
                       model_names=GRU1_model_names,
                       model_designs=GRU1_model_designs,
                       save_path=GRU1_save_path,
                       cell_type='GRU',
                       dataset='validation',
                       nr_epochs=9,
                       figsize=(4.5,4.5),
                       ylim=(0,98),
                       skip_epoch=[('DirectedProp\none epoch',1)],
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Pre-trained for two and four epochs - Vanilla RNN

# %%
RNN2_4_parent_dir = f'{config.project_dir}/Output/NI_maze/RNN'
RNN2_4_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_TWO_EPOCHS', 'Pretrained_Directional_FOUR_EPOCHS']
RNN2_4_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\ntwo epochs', 'DirectedProp\nfour epochs']
RNN2_4_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                        {'color': '#4cc997', 'marker': 'v'},
                        {'color': '#e699ff', 'marker': 'P'},
                        {'color': '#f1854f', 'marker': 'P'}]
RNN2_4_save_path = "figures_revisions/Figure_4/"

# %%
plot_mse_with_break(parent_dir=RNN2_4_parent_dir,
                    model_dirs=RNN2_4_model_dirs, 
                    model_names=RNN2_4_model_names, 
                    model_designs=RNN2_4_model_designs, 
                    save_path=RNN2_4_save_path, 
                    cell_type='RNN', 
                    dataset='train', 
                    figsize=(6,4.5),
                    ylim=(0,175), 
                    start_break=20, 
                    end_break=40, 
                    width_ratios=[5,1.2], 
                    skip_epoch=[('DirectedProp\ntwo epochs',2), 
                                ('DirectedProp\nfour epochs',4)],
                    )
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN2_4_parent_dir,
                    model_dirs=RNN2_4_model_dirs, 
                    model_names=RNN2_4_model_names, 
                    model_designs=RNN2_4_model_designs, 
                    save_path=RNN2_4_save_path, 
                    cell_type='RNN', 
                    dataset='validation', 
                    figsize=(6,4.5), 
                    ylim=(0,127), 
                    start_break=20, 
                    end_break=40, 
                    width_ratios=[5,1.2], 
                    skip_epoch=[('DirectedProp\ntwo epochs',2), 
                                ('DirectedProp\nfour epochs',4)],
                    )
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Supplementary: Pre-training controls

# %% [markdown]
# ## Pre-trained with undirectioanal RWs

# %%
RNN_parent_dir = f'{config.project_dir}/Output/NI_maze/RNN'
RNN_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Pretrained_UNdirectional']
RNN_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained',
                'Pre-trained with\nRWs propagating in\nall directions']
RNN_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                     {'color': '#d6a319', 'marker': 'x'},
                     {'color': '#4cc997', 'marker': 'v'},
                     {'color': '#cc0099', 'marker': '*'}]
RNN_save_path = 'figures_revisions/Figure_S1'

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,175),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,127),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Pre-trained with moving square

# %%
RNN_parent_dir = f'{config.project_dir}/Output/NI_maze/RNN'
RNN_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Pretrained_MovingSquare']
RNN_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained',
                'Pre-trained with\nmoving square']
RNN_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                     {'color': '#d6a319', 'marker': 'x'},
                     {'color': '#4cc997', 'marker': 'v'},
                     {'color': '#cc0099', 'marker': '*'}]
RNN_save_path = 'figures_revisions/Figure_S1'

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,175),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,127),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Pre-trained with RWs with Gaussian Blur

# %%
RNN_parent_dir = f'{config.project_dir}/Output/NI_maze/RNN'
RNN_model_dirs = ['Pretrained_Directional', 'Pretrained_Godfrey', 'No_Pretraining', 'Pretrained_RWGaussianBlur']
RNN_model_names = ['DirectedProp', 'NotDirectedProp', 'NotPretrained',
                'Pre-trained with\nRWs with Gaussian Blur']
RNN_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                     {'color': '#d6a319', 'marker': 'x'},
                     {'color': '#4cc997', 'marker': 'v'},
                     {'color': '#cc0099', 'marker': '*'}]
RNN_save_path = 'figures_revisions/Figure_S1'

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,175),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_parent_dir,
                    model_dirs=RNN_model_dirs,
                    model_names=RNN_model_names,
                    model_designs=RNN_model_designs,
                    save_path=RNN_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,127),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=40,
                    width_ratios=[5,1.2])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # CatCam dataset

# %%
RNN_catcam_parent_dir = f'{config.cloud_project_dir}/01_Output/Training_Output/CatCam_Dataset/RNN'
RNN_catcam_model_dirs = ['Pretrained_Directional', 'No_Pretraining']
RNN_catcam_model_names = ['DirectedProp', 'NotPretrained']
RNN_catcam_model_designs = [{'color': '#0065bd', 'marker': 'o'},
                 {'color': '#4cc997', 'marker': 'v'}]
RNN_catcam_save_path = 'figures_revisions/Figure_3'

# %%
plot_mse_without_break(parent_dir=RNN_catcam_parent_dir,
                       model_dirs=RNN_catcam_model_dirs,
                       model_names=RNN_catcam_model_names,
                       model_designs=RNN_catcam_model_designs,
                       save_path=RNN_catcam_save_path,
                       cell_type='RNN',
                       dataset='train',
                       nr_epochs=24,
                       figsize=(6,4.5),
                       ylim=(73,170),
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_without_break(parent_dir=RNN_catcam_parent_dir,
                       model_dirs=RNN_catcam_model_dirs,
                       model_names=RNN_catcam_model_names,
                       model_designs=RNN_catcam_model_designs,
                       save_path=RNN_catcam_save_path,
                       cell_type='RNN',
                       dataset='validation',
                       nr_epochs=24,
                       ylim=(75,142),
                       figsize=(6,4.5),
                       show_legend=True)
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Looming Size

# %%
RNN_loom_size_parent_dir = f'{config.project_dir}/Output/Looming_Size/RNN'
RNN_loom_size_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
RNN_loom_size_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
RNN_loom_size_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
RNN_loom_size_save_path = 'figures_revisions/Figure_S3/looming_size'

# %%
plot_mse_with_break(parent_dir=RNN_loom_size_parent_dir,
                    model_dirs=RNN_loom_size_model_dirs,
                    model_names=RNN_loom_size_model_names,
                    model_designs=RNN_loom_size_model_designs,
                    save_path=RNN_loom_size_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,250),
                    figsize=(5,4.5),
                    start_break=15,
                    end_break=25,
                    xlim_max=29,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_loom_size_parent_dir,
                    model_dirs=RNN_loom_size_model_dirs,
                    model_names=RNN_loom_size_model_names,
                    model_designs=RNN_loom_size_model_designs,
                    save_path=RNN_loom_size_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,150),
                    figsize=(5,4.5),
                    start_break=15,
                    end_break=25,
                    xlim_max=29,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Looming Color

# %%
RNN_loom_color_parent_dir = f'{config.project_dir}/Output/Looming_Color/RNN'
RNN_loom_color_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
RNN_loom_color_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
RNN_loom_color_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
RNN_loom_color_save_path = 'figures_revisions/Figure_S3/looming_color'

# %%
plot_mse_with_break(parent_dir=RNN_loom_color_parent_dir,
                    model_dirs=RNN_loom_color_model_dirs,
                    model_names=RNN_loom_color_model_names,
                    model_designs=RNN_loom_color_model_designs,
                    save_path=RNN_loom_color_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,160),
                    figsize=(5,4.5),
                    start_break=15,
                    end_break=30,
                    xlim_max=34,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_loom_color_parent_dir,
                    model_dirs=RNN_loom_color_model_dirs,
                    model_names=RNN_loom_color_model_names,
                    model_designs=RNN_loom_color_model_designs,
                    save_path=RNN_loom_color_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,60),
                    figsize=(5,4.5),
                    start_break=15,
                    end_break=30,
                    xlim_max=34,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Human Action

# %%
RNN_human_action_parent_dir = f'{config.project_dir}/Output/Human_Action/RNN'
RNN_human_action_model_dirs = ['Pretrained_Directional', 'No_Pretraining', 'Pretrained_Directional_ONE_EPOCH']
RNN_human_action_model_names = ['DirectedProp', 'NotPretrained', 'DirectedProp\none epoch']
RNN_human_action_model_designs = [{'color': '#0065bd', 'marker': 'o'}, {'color': '#4cc997', 'marker': 'v'}, {'color': '#bf4492', 'marker': 'P'}]
RNN_human_action_save_path = 'figures_revisions/Figure_S3/human_action'

# %%
plot_mse_with_break(parent_dir=RNN_human_action_parent_dir,
                    model_dirs=RNN_human_action_model_dirs,
                    model_names=RNN_human_action_model_names,
                    model_designs=RNN_human_action_model_designs,
                    save_path=RNN_human_action_save_path,
                    cell_type='RNN',
                    dataset='train',
                    ylim=(0,90),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=30,
                    xlim_max=35,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_mse_with_break(parent_dir=RNN_human_action_parent_dir,
                    model_dirs=RNN_human_action_model_dirs,
                    model_names=RNN_human_action_model_names,
                    model_designs=RNN_human_action_model_designs,
                    save_path=RNN_human_action_save_path,
                    cell_type='RNN',
                    dataset='validation',
                    ylim=(0,30),
                    figsize=(6,4.5),
                    start_break=20,
                    end_break=30,
                    xlim_max=35,
                    width_ratios=[5,1.2],
                    skip_epoch=[('DirectedProp\none epoch',1)])
# Out:
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/scipy/stats/_stats_py.py:831: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return a.var(ddof=ddof, axis=axis)
# /Users/lillymay/opt/anaconda3/envs/RetinalWave_model/lib/python3.8/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
